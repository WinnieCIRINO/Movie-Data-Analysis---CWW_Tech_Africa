# %%
'''Task 1
Create a list of years from 2011 to 2020 and a list durations of the average movie lengths our friend provided 
(103, 101, 99, 100, 100, 95, 95,96, 93. and 90) Create a dictionary movie_dict, with the keys years" and "durations"
 and the values set to your lists years and durations Print and inspect the dictionlsy to ensure was created correctly'''
 
#List of years from 2011 to 2020
years = (2011,2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020)

#List duration of average movie length
durations = (103, 101, 99, 100, 100, 95, 95, 96,93, 90 )

#Create movie_dict dictionary
movie_dict = {"years": years , "durations": durations}

#Print movie_dict
print(movie_dict)
# Out:
# {'years': (2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020), 'durations': (103, 101, 99, 100, 100, 95, 95, 96, 93, 90)}

# %%
'''Task 2: 
Import pandas using its usual alias, pd. 
Create  a DataFrame durations_df using your movie_dict dictionary you created in the previous step.'''

import pandas as pd

#Previously created movie_dict dictionary
movie_dict = {'years': (2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020), 
              'durations': (103, 101, 99, 100, 100, 95, 95, 96, 93, 90)}


#Create DataFrame durations_df
durations_df = pd.DataFrame(movie_dict)

#Print entire DataFrame
print(durations_df)
# Out:
#    years  durations
# 0   2011        103
# 1   2012        101
# 2   2013         99
# 3   2014        100
# 4   2015        100
# 5   2016         95
# 6   2017         95
# 7   2018         96
# 8   2019         93
# 9   2020         90

# %%
'''Task 3: 
Import matplotlib.pyplot under the alias plt 
Create a line plot of the data with the years column of durations _df on the x|axis, and the durations column on the y- axis.
 Add the title Netflix Movie Durations 201 1-2020" to your plot'''
import pandas as pd 
import matplotlib.pyplot as plt

#Create a figure and icrease the figure  size
fig = plt.figure(figsize = (12,8))

#Line plot of the data durations_df with years on X-axis and durations column on y-axis
plt.plot(durations_df ['years'] , durations_df ['durations'])

#Adding labels and title
plt.xlabel ('years')
plt.ylabel ('durations')
plt.title ('Netflix Movie Durations 2011 - 2020')

#Show the plot
plt.show()

# %%
'''Task 4 
Create another DataFrame, netflix_df, this time using the CSV file our friend provided us with, 
available at the path "datasets/netflix_data.csv" Print the first five rows of the DataFrame to inspect the data 
and ensure it was created successfully. '''

#Create a DataFrame 'netflix_df'
import pandas as pd
netflix_df = pd.read_csv('D:/CTA Folder/datasets/netflix_data.csv')
#Print the first five rows of the DartaFrame
print(netflix_df.head(5))
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
'''Task 5
Subset the netflix_df DataFrame such that only rows where the type is a "Movie" are preserved. 
Assign the result to netflix_df_movies_only. 

Subset the netflix_df_movies_only DataFrame to preserve only the columns 
title, country, genre, release_year, and duration. Assign the result to netflix_movies_col_subset 
Print the first five rows of netflix_movies_col_subset '''

#Subset for "Movie" type
netflix_df_movies_only = netflix_df[netflix_df ['type'] == 'Movie']

 #Subset columns title, country, genre, release_year, and duration
netflix_movies_col_subset = netflix_df_movies_only [['title' , 'country' , 'genre', 'release_year', 'duration'] ]
print(netflix_movies_col_subset.head(5))
# Out:
#    title        country          genre  release_year  duration
# 1   7:19         Mexico         Dramas          2016        93
# 2  23:59      Singapore  Horror Movies          2011        78
# 3      9  United States         Action          2009        80
# 4     21  United States         Dramas          2008       123
# 6    122          Egypt  Horror Movies          2019        95

# %%
'''Task 6
Using your netflix_movies _col_subset DataFrame, create a scatter plot, placing the release_year on the x-axis 
and the movie duration on the y-axis tons Add a title to your plot: "Movie Duration by Year of Release" Show the plot'''
import pandas as pd
import matplotlib.pyplot as pd

#Create a figure and increase the figure size
fig =  plt.figure(figsize=(12,8))

#Create a scatter plot using netflix_movies_col_subnet
plt.scatter(netflix_movies_col_subset ['release_year'] , netflix_movies_col_subset ['duration'])

#Add title and labels
plt.xlabel('release_year')
plt.ylabel('duration')
plt.title('Movie Duration by Year of Release')

#Show the plot
plt.show()

# %%
'''Task 7
Subset netflix_movies_col_subset to create a new DataFrame short _movies containing only movies that have a duration 
fewer than 60 minutes Print the first 20 rows of short_movies to get a good overview of the types of films with a short duration '''

#Create new DataFrame "short_novies" 
short_movies= netflix_movies_col_subset[netflix_movies_col_subset['duration']< 60]

#print the first 20 rows of short_movies
print(short_movies.head(20))
# Out:
#                                                  title         country  \
# 35                                           #Rucker50   United States
# 55                 100 Things to do Before High School   United States
# 67   13TH: A Conversation with Oprah Winfrey & Ava ...             NaN
# 101                                  3 Seconds Divorce          Canada
# 146                                     A 3 Minute Hug          Mexico
# 162  A Christmas Special: Miraculous: Tales of Lady...          France
# 171                         A Family Reunion Christmas   United States
# 177                    A Go! Go! Cory Carson Christmas   United States
# 178                    A Go! Go! Cory Carson Halloween             NaN
# 179                  A Go! Go! Cory Carson Summer Camp             NaN
# 181             A Grand Night In: The Story of Aardman  United Kingdom
# 200                            A Love Song for Latasha   United States
# ...

# %%
'''Task 8 
Initialize an empty list called colors to store our different color values Use a for loop to iterate through 
the netflix_movies_col_subset DataFrame's rows and append colors to your colors list based on the following conditions: 
lf the genre is " Children", append "red" 
lf the genre is "Documentaries". append "blue" 
lf the genre is "Stand-Up", append "green".
lf the genre is any other genre, append "black"
Print the first 10 values of your colors list to inspect the results'''

#Initialize an empty list for colors
colors = []

# #Iterate through rows and append colors based on genre
for genre in netflix_movies_col_subset ['genre']:
    if genre == 'Children' : colors.append('red')
    if genre == 'Documentaries' :colors.append('blue')
    if genre == 'Stand-Up' : colors.append('green')
    else : colors.append('black')

print (colors[:10])
# Out:
# ['black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'black', 'blue']

# %%
'''Task 9
Using the data contained in netflix_movies _col_subset, plot the same scatter plot 
as you did in Task 6, but with a few modifications 
Color the points on the scatter plot using your colors list you defined in the previous step 
Add a title Movie duration by year of release". an x-axis A label "Release year", 
and a y-axis label "Duration (min Show the plot '''

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,8))

# Create a scatter plot of duration versus release_year
plt.scatter(netflix_movies_col_subset["release_year"], netflix_movies_col_subset["duration"] , , c=colors)

# Create a title and axis labels
plt.xlabel("Release Years")
plt.ylabel("Durations (minutes)")
plt.title("Movie Duration by Year of Release")

# Show the plot
plt.show()

# %%
'''Task 10
Provide your answer to the question " Are we certain that movies are getting shorter?" in the form of a string DATA SETS'''

#Are we certain that movies are getting shorter.
Answer = '''The scatter plot shows a range of movie durations over different years, 
and much  as there are movies with shorter durations, this scatter plot does not give 
a clear trend that movies are consistently getting shorter. '''
print (Answer)
